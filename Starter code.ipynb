# %%
import pandas as pd

# %%
citibikes_data = ["resources/202208.csv", "resources/202209.csv", "resources/202210.csv", "resources/202211.csv", "resources/202212.csv"]

# %%
# Create an empty list to store each dataframe
citibikes_list = []

# Loop through each file in the list
for data in citibikes_data:
    # Read the file into a dataframe
    citibikes = pd.read_csv(data)

    # Append the dataframe to the list
    citibikes_list.append(citibikes)

# Concatenate all dataframes in the list into one dataframe
citibikes_df = pd.concat(citibikes_list)

# Show dataframe
citibikes_df
# Out:
# C:\Users\tonyn\AppData\Local\Temp\ipykernel_26548\3532138886.py:7: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   citibikes = pd.read_csv(data)
# C:\Users\tonyn\AppData\Local\Temp\ipykernel_26548\3532138886.py:7: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   citibikes = pd.read_csv(data)
# C:\Users\tonyn\AppData\Local\Temp\ipykernel_26548\3532138886.py:7: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   citibikes = pd.read_csv(data)
# C:\Users\tonyn\AppData\Local\Temp\ipykernel_26548\3532138886.py:7: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   citibikes = pd.read_csv(data)
# C:\Users\tonyn\AppData\Local\Temp\ipykernel_26548\3532138886.py:7: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
citibikes_df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
citibikes_df.isnull().values.any()
# Out:
# True

# %%
citibikes_df.dropna(inplace = True)
citibikes_df
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        428051654CF1145B   classic_bike  2022-08-28 00:34:58
# 1        7282036E3ECDDD65   classic_bike  2022-08-31 16:33:38
# 2        375C59BE1271E31C  electric_bike  2022-08-27 23:22:10
# 3        7281A7F21CE571AF   classic_bike  2022-08-26 19:01:01
# 4        A5093D7D77713F87   classic_bike  2022-08-25 22:16:16
# ...                   ...            ...                  ...
# 1649647  CB2EE50F60A58C7B   classic_bike  2022-12-12 08:38:46
# 1649648  3C0DF3280FEB1350   classic_bike  2022-12-12 13:06:32
# 1649649  B916E63B630D5020   classic_bike  2022-12-18 01:15:22
# 1649650  21EAC007BE7D4161   classic_bike  2022-12-08 23:09:54
# 1649651  538408C4A16F4415  electric_bike  2022-12-21 07:26:14
#
#                     ended_at                 start_station_name  \
# 0        2022-08-28 00:55:20              Walker St & Baxter St
# 1        2022-08-31 16:35:17            Lexington Ave & E 29 St
# ...

# %%
citibikes_df.to_csv("resources/citibikes_combine_2.csv", index=False)
